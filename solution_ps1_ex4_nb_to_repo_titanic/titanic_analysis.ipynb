# %%
# Create a histogram for age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=train_data, x='Age', hue='Survived', multiple="stack", kde=True)
plt.title("Age Distribution of Survivors vs Non-Survivors")
plt.xlabel("Age")
plt.ylabel("Count")
plt.savefig("figures/age_distribution.png")  # Save the figure
plt.show()

# %%
# Create a new feature for family size
train_data['FamilySize'] = train_data['SibSp'] + train_data['Parch']

# Plot survival rate by family size
plt.figure(figsize=(10, 6))
sns.barplot(x='FamilySize', y='Survived', data=train_data, ci=None)
plt.title("Survival Rate by Family Size")
plt.xlabel("Family Size")
plt.ylabel("Survival Rate")
plt.savefig("figures/survival_by_family_size.png")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\414491877.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='FamilySize', y='Survived', data=train_data, ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=train_data, ci=None)
plt.title("Survival Rate by Passenger Class and Gender")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.legend(title="Sex")
plt.savefig("figures/survival_by_class_and_gender.png")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3251007766.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', hue='Sex', data=train_data, ci=None)

# %%
# Create fare bins
train_data['FareBin'] = pd.qcut(train_data['Fare'], 4, labels=['Low', 'Medium', 'High', 'Very High'])

# Plot survival rate by fare bin
plt.figure(figsize=(10, 6))
sns.barplot(x='FareBin', y='Survived', data=train_data, ci=None)
plt.title("Survival Rate by Fare Bins")
plt.xlabel("Fare Bin")
plt.ylabel("Survival Rate")
plt.savefig("figures/survival_by_fare_bins.png")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1013432065.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='FareBin', y='Survived', data=train_data, ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Embarked', y='Survived', hue='Pclass', data=train_data, ci=None)
plt.title("Survival Rate by Embarkation Point and Passenger Class")
plt.xlabel("Embarkation Point")
plt.ylabel("Survival Rate")
plt.legend(title="Passenger Class")
plt.savefig("figures/survival_by_embark_and_class.png")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\305225225.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Embarked', y='Survived', hue='Pclass', data=train_data, ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=train_data, alpha=0.6)
plt.title("Survival by Age and Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="Survived")
plt.savefig("figures/survival_by_age_and_fare.png")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
train_data = pd.read_csv('data/train.csv')
# Create a bar plot for survival by embarkation point
plt.figure(figsize=(8, 6))
sns.barplot(x='Embarked', y='Survived', data=train_data, ci=None)
plt.title("Survival Rate by Embarkation Point")
plt.xlabel("Embarked")
plt.ylabel("Survival Rate")
plt.savefig("figures/survival_by_embarked.png")  # Save the figure
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1785197899.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Embarked', y='Survived', data=train_data, ci=None)

# %%
# Create a box plot for fare by survival
plt.figure(figsize=(10, 6))
sns.boxplot(x='Survived', y='Fare', data=train_data)
plt.title("Fare Distribution by Survival")
plt.xlabel("Survived")
plt.ylabel("Fare")
plt.savefig("figures/fare_distribution.png")  # Save the figure
plt.show()

# %%
# Create a bar plot for survival by sex
plt.figure(figsize=(8, 6))
sns.barplot(x='Sex', y='Survived', data=train_data, ci=None)
plt.title("Survival Rate by Sex")
plt.xlabel("Sex")
plt.ylabel("Survival Rate")
plt.savefig("figures/survival_by_sex.png")  # Save the figure
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22396\1997483066.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=train_data, ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot for survival by class
plt.figure(figsize=(8, 6))
sns.barplot(x='Pclass', y='Survived', data=train_data, ci=None)
plt.title("Survival Rate by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.savefig("figures/survival_by_class.png")  # Save the figure
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22396\177343844.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', data=train_data, ci=None)

# %%
import pandas as pd

# Load the dataset
train_data = pd.read_csv('data/train.csv')
test_data = pd.read_csv('data/test.csv')

train_data.head()  # Display the first few rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
